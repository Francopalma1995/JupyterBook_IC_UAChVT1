# %% [markdown]
# <img src="../figuras/hormigon.jpg" width="700">
#
#
# # Hormigonado
#
#
# <img src="../figuras/indiceHmgdo.png" width="1000">

# %% [markdown]
# <img src="../figuras/Hregistro_7.png" width="400">
#
#
#
# ## Diagrama de Flujo – “Trabajo Previo del Hormigón”
#
#
#
# <img src="../figuras/fundacion_Htp.png">
#
# <cite data-cite="vega2018you3">(Vega,2018)</cite>
#
#
#
# ## Diagrama de Flujo – “Hormigón en Losa de Fundación y Losa Cielo”
#
#
# <img src="../figuras/hormigon_lfyc_1.png">
#
# <img src="../figuras/hormigon_lfyc_2.png">
#
# <img src="../figuras/hormigon_lfyc_3.png">
#
# <img src="../figuras/hormigon_lfyc_4.png">
#
# <cite data-cite="vega2018you3">(Vega,2018)</cite>
#
#
#
# ## Diagrama de Flujo – “Hormigón en Muros y Pilares”
#
#
# <img src="../figuras/hormigon_MyP_1.png">
#
# <img src="../figuras/hormigon_MyP_2.png">
#
# <img src="../figuras/hormigon_MyP_3.png">
#
#
# <cite data-cite="vega2018you3">(Vega,2018)</cite>
#
#
#
# ## Diagrama de Flujo – “Hormigón de Vigas”
#
#
# <img src="../figuras/hormigon_V_1.png">
#
# <img src="../figuras/hormigon_V_2.png">
#
# <img src="../figuras/hormigon_V_3.png">
#
#
# <cite data-cite="vega2018you3">(Vega,2018)</cite>
#
#
#
# ## Diagrama de Flujo – “Recepción del Hormigon en Obra”
#
#
# <img src="../figuras/hormigon_Recep.png">
#
#
# <cite data-cite="vega2018you3">(Vega,2018)</cite>
#
#
#
# ## Diagrama de Flujo – “Capacho”
#
#
# <img src="../figuras/hormigon_Capacho.png">
#
#
# <cite data-cite="vega2018you3">(Vega,2018)</cite>
#
#
#
# ## Diagrama de Flujo – “Instalación de Camión Bomba”
#
#
# <img src="../figuras/hormigon_Bomba.png">
#
#
# <cite data-cite="vega2018you3">(Vega,2018)</cite>
#
#
#
# ## Diagrama de Flujo – “Vibrado del Hormigón”
#
#
# <img src="../figuras/hormigon_Vibrado_1.png">
#
# <img src="../figuras/hormigon_Vibrado_2.png">
#
#
# <cite data-cite="vega2018you3">(Vega,2018)</cite>

# %% [markdown]
# <img src="../figuras/registro_7.png" width="400">
#
#
#
# ## Lista de Verificación de Emplantillado
#
#
# <img src="../figuras/l_v_emp.png">
#
# <cite data-cite="Almonacid2020you3">(Almonacid,2020)</cite>

# %% [markdown]
# ## Lista de Verificación de Hormigón Fundación, Muro, Pilares y Vigas
#
#
# <img src="../figuras/l_v_hfmpv.png">
#
# <cite data-cite="Almonacid2020you3">(Almonacid,2020)</cite>

# %% [markdown]
# ## Lista de Verificación Hormigón de Losas
#
#
#
# <img src="../figuras/l_v_hl.png">
#
# <cite data-cite="Almonacid2020you3">(Almonacid,2020)</cite>

# %% [markdown]
# ## Protocolo de Recepción de Hormigones
#
#
#
# <img src="../figuras/p_r_h.png">
#
# <cite data-cite="Almonacid2020you3">(Almonacid,2020)</cite>
